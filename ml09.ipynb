# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Análise Exploratória de Dados

# %%
df = pd.read_excel(r'C:\Nucleo_IA\COVID\ml_covid\dataset_alta.xlsx')

# %%
df.head(15)
# Out:
#     idade sexo    raca tagabismo comorbidade1 comorbidade2 comorbidade3  \
# 0      41    M  branca       nao      nenhuma      nenhuma       nenhum
# 1      77    F  branca       sim          HAS      nenhuma       nenhum
# 2      67    M  branca    previo          HAS           DM       nenhum
# 3      51    M  branca       nao          HAS     renal-hd       nenhum
# 4      51    M  branca       nao          HAS     renal-hd       nenhum
# 5      64    F  branca       nao          HAS      nenhuma       nenhum
# 6      38    M   preta       nao     renal-hd      nenhuma       nenhum
# 7      37    M  branca       sim          HIV   oncologico       nenhum
# 8      82    F  branca       nao          HAS   oncologico       nenhum
# 9      45    M  branca       nao      nenhuma      nenhuma       nenhum
# 10     63    M  branca    previo          HAS           DM   oncologica
# 11     79    M   preta       nao          HAS      nenhuma       nenhum
# 12     79    M  branca       nao          HAS      nenhuma       nenhum
# 13     52    F   preta       nao           DM      nenhuma       nenhum
# 14     30    M   preta       sim          HIV      nenhuma       nenhum
#
#    comorbidade4 trombo_na_internacao  desfecho  \
# 0        nenhum               nenhum         0
# 1        nenhum               nenhum         0
# 2        nenhum               nenhum         0
# 3        nenhum               nenhum         1
# 4        nenhum               nenhum         1
# 5        nenhum               nenhum         1
# 6        nenhum               nenhum         1
# 7        nenhum                  TVP         0
# 8        nenhum               nenhum         0
# 9        nenhum                ambos         0
# 10       nenhum               nenhum         0
# 11       nenhum               nenhum         1
# 12       nenhum               nenhum         0
# 13       nenhum                  TEP         1
# 14       nenhum               nenhum         1
#
#                 anti-inflamatorio1    anti-inflamatorio2 anti-inflamatorio3  \
# 0                           nenhum                nenhum             nenhum
# 1             hidrocortisona 100mg       prednisona 20mg             nenhum
# 2                           nenhum                nenhum             nenhum
# 3                  prednisona 20mg                nenhum             nenhum
# 4   denenhumametasona 4mg/mL 2,5mL  hidrocortisona 100mg    prednisona 20mg
# 5                           nenhum                nenhum             nenhum
# 6             hidrocortisona 100mg       prednisona 20mg             nenhum
# 7                    tiamina 300mg  piridonenhumina 40mg             nenhum
# 8                           nenhum                nenhum             nenhum
# 9                           nenhum                nenhum             nenhum
# 10                 prednisona 20mg                nenhum             nenhum
# 11                          nenhum                nenhum             nenhum
# 12  denenhumametasona 4mg/mL 2,5mL                nenhum             nenhum
# 13                          nenhum                nenhum             nenhum
# 14            piridonenhumina 40mg                nenhum             nenhum
#
#    anti-inflamatorio_previo        profilaxia_de_trombo1  \
# 0                       Nao       heparina 5000UI/0,25mL
# 1                       Nao  enonenhumaparina 40mg/0,4mL
# 2                       Nao       heparina 5000UI/0,25mL
# 3                       Sim                       nenhum
# 4                       Nao                       nenhum
# 5                       Nao       heparina 5000UI/0,25mL
# 6                       Sim       heparina 5000UI/0,25mL
# 7                       Nao  enonenhumaparina 40mg/0,4mL
# 8                       Nao  enonenhumaparina 40mg/0,4mL
# 9                       Nao  enonenhumaparina 40mg/0,4mL
# 10                      Sim       heparina 5000UI/0,25mL
# 11                      Nao       heparina 5000UI/0,25mL
# 12                      Nao       heparina 5000UI/0,25mL
# 13                      Nao       heparina 5000UI/0,25mL
# 14                      Sim                       nenhum
#
#           profilaxia_de_trombo2 anticoagulante_previo antibiotico1  \
# 0                        nenhum                   Sim          NaN
# 1                        nenhum                   Sim          NaN
# 2                        nenhum                   Sim          NaN
# 3                        nenhum                   Nao          NaN
# 4                        nenhum                   Nao          NaN
# 5                        nenhum                   Sim          NaN
# 6                        nenhum                   Nao          NaN
# 7                        nenhum                   Sim          NaN
# 8                        nenhum                   Sim          NaN
# 9   enonenhumaparina 60mg/0,6mL                   Sim          NaN
# 10                       nenhum                   Sim          NaN
# 11                       nenhum                   Sim          NaN
# 12                       nenhum                   Nao          NaN
# 13                       nenhum                   Sim          NaN
# 14                       nenhum                   Nao          NaN
#
#    antibiotico2  proteina c (mg/dl)  ferritina (ng/ml)  leucócitos ( /ul)  \
# 0           NaN                 8.0                  0               4830
# 1           NaN                14.7                  0               5280
# 2           NaN                 0.0                  0               8650
# 3           NaN                 6.2                  0               9590
# 4           NaN                32.0                  0               4230
# 5           NaN                 4.1               1530               6430
# 6           NaN                19.3               2380               1260
# 7           NaN                 4.8                  0               4410
# 8           NaN                 0.0                  0                  0
# 9           NaN                17.2                366               2790
# 10          NaN                 8.8                  0               4480
# 11          NaN                 0.0                  0              11150
# 12          NaN                21.1                  0              10260
# 13          NaN                 2.1                  0               4510
# 14          NaN                 5.1                  0               2560
#
#     creatinina (mg/dl)  ureia(mg/dl)  d-dimeros (ng/ml) reinfeccao  sintomas
# 0                 0.76          36.0                  0        nao      leve
# 1                 0.82          31.0                  0        nao  assintom
# 2                 0.72           0.0                  0        nao      leve
# 3                 0.00         142.0                  0        nao      leve
# 4                15.40         158.0               1535        sim  assintom
# 5                 1.00          52.0                  0        nao      leve
# 6                 7.35         191.0               1021        nao      leve
# 7                 0.68          31.0                437        nao      leve
# 8                 0.00           0.0                  0        nao  assintom
# 9                 1.08          22.0                  0        nao      leve
# 10                1.33          61.0               3760        nao     grave
# 11                0.89          53.0                  0        nao  assintom
# 12                1.09          62.0               1657        sim  moderado
# 13                1.12          22.0               2466        nao      leve
# 14                1.09          22.0                  0        sim      leve

# %% [markdown]
# Valores Vazios
# - Deletar linhas/colunas vazias
# - Deletar linhas que possuem valores vazios
# - Preencher valores vazios (último valor)

# %%
# deletar linhas e colunas completamente vazias
# df = df.dropna(how='all', axis=1)

# deletar linhas que possuem pelo menos 1 valor vazio
# df = df.dropna()

# %%
# preencher com o último valor
df = df.ffill()

# %%
# deletar colunas incompletas
df = df.drop(columns='antibiotico1')
df = df.drop(columns='antibiotico2')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   idade                     429 non-null    int64
#  1   sexo                      429 non-null    object
#  2   raca                      429 non-null    object
#  3   tagabismo                 429 non-null    object
#  4   comorbidade1              429 non-null    object
#  5   comorbidade2              429 non-null    object
#  6   comorbidade3              429 non-null    object
#  7   comorbidade4              429 non-null    object
#  8   trombo_na_internacao      429 non-null    object
#  9   desfecho                  429 non-null    int64
#  10  anti-inflamatorio1        429 non-null    object
#  11  anti-inflamatorio2        429 non-null    object
#  12  anti-inflamatorio3        429 non-null    object
#  13  anti-inflamatorio_previo  429 non-null    object
#  14  profilaxia_de_trombo1     429 non-null    object
#  15  profilaxia_de_trombo2     429 non-null    object
#  16  anticoagulante_previo     429 non-null    object
#  17  proteina c (mg/dl)        429 non-null    float64
#  18  ferritina (ng/ml)         429 non-null    int64
#  19  leucócitos ( /ul)         429 non-null    int64
#  20  creatinina (mg/dl)        429 non-null    float64
#  21  ureia(mg/dl)              429 non-null    float64
#  22  d-dimeros (ng/ml)         429 non-null    int64
#  23  reinfeccao                429 non-null    object
#  24  sintomas                  429 non-null    object
# dtypes: float64(3), int64(5), object(17)
# memory usage: 83.9+ KB

# %%
view_comorbidade_desfecho = df[['comorbidade1','comorbidade2','comorbidade3','comorbidade4', 'desfecho']]
display(view_comorbidade_desfecho)
# Out:
#     comorbidade1 comorbidade2 comorbidade3 comorbidade4  desfecho
# 0        nenhuma      nenhuma       nenhum       nenhum         0
# 1            HAS      nenhuma       nenhum       nenhum         0
# 2            HAS           DM       nenhum       nenhum         0
# 3            HAS     renal-hd       nenhum       nenhum         1
# 4            HAS     renal-hd       nenhum       nenhum         1
# ..           ...          ...          ...          ...       ...
# 424          HAS      nenhuma       nenhum       nenhum         1
# 425      nenhuma      nenhuma       nenhum       nenhum         0
# 426           DM          HAS       nenhum       nenhum         1
# 427          HAS          ICC       nenhum       nenhum         0
# 428           DM          HAS       nenhum       nenhum         1
#
# [429 rows x 5 columns]

# %%
df['desfecho']==1  # DESFECHO (1-alta/ 2-UTI/ 3-óbito/4-fim isolamento/5-transf.)
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 424     True
# 425    False
# 426     True
# 427    False
# 428     True
# Name: desfecho, Length: 429, dtype: bool

# %% [markdown]
# #### Atributos escolhidos:

# %%
nomes_atributos_numericos = ['idade','proteina c (mg/dl)','ferritina (ng/ml)','leucócitos ( /ul)','creatinina (mg/dl)','ureia(mg/dl)','d-dimeros (ng/ml)']

# %%
nomes_atributos_numericos
# Out:
# ['idade',
#  'proteina c (mg/dl)',
#  'ferritina (ng/ml)',
#  'leucócitos ( /ul)',
#  'creatinina (mg/dl)',
#  'ureia(mg/dl)',
#  'd-dimeros (ng/ml)']

# %%
nomes_atributos_categoricos = ['sexo','sintomas','raca','tagabismo','comorbidade1','comorbidade2','comorbidade3','comorbidade4','trombo_na_internacao','sintomas','anti-inflamatorio_previo','anticoagulante_previo','reinfeccao']

# %%
nomes_atributos_categoricos
# Out:
# ['sexo',
#  'sintomas',
#  'raca',
#  'tagabismo',
#  'comorbidade1',
#  'comorbidade2',
#  'comorbidade3',
#  'comorbidade4',
#  'trombo_na_internacao',
#  'sintomas',
#  'anti-inflamatorio_previo',
#  'anticoagulante_previo',
#  'reinfeccao']

# %%
df['desfecho'].value_counts()
# Out:
# 1    243
# 0    186
# Name: desfecho, dtype: int64

# %% [markdown]
# #### Pré-Processamento

# %% [markdown]
# #### Separando os conjuntos de treino e teste

# %%
from sklearn.model_selection import train_test_split

# separando os conjuntos de dados de treino e teste
df_treino, df_teste = train_test_split(df, test_size=0.2, random_state=42)

# separando a coluna alvo do conjunto de treino
df_treino_labels = df_treino['desfecho'].copy()
df_treino        = df_treino.drop(columns='desfecho')

# separando a coluna alvo do conjunto de teste
df_teste_labels = df_teste['desfecho'].copy()
df_teste        = df_teste.drop(columns='desfecho')

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

pipeline_atr_numericos = Pipeline([
    ('imputer',SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler()),
])

preproc_completo = ColumnTransformer([
    ('numericos',   pipeline_atr_numericos, nomes_atributos_numericos),
    ('categoricos', OneHotEncoder(),        nomes_atributos_categoricos),
    ], 
    sparse_threshold=0)

# pre-processamento do conjunto de treino
X_treino = preproc_completo.fit_transform(df_treino)

# pre-processamento do conjunto de teste
X_teste = preproc_completo.transform(df_teste)

# pre-processamento da coluna alvo para treino
y_treino = df_treino_labels.values == 1

# pre-processamento da coluna alvo para teste
y_teste = df_teste_labels.values == 1

# %%
import tensorflow as tf
from tensorflow import keras

# %%
X_treino
# Out:
# array([[ 0.55880269,  0.66566491, -0.27504492, ...,  1.        ,
#          1.        ,  0.        ],
#        [-1.31686041, -0.96869008, -0.27504492, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.26573033,  1.70320488, -0.27504492, ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [-0.43764333, -0.6289646 , -0.27504492, ...,  1.        ,
#          1.        ,  0.        ],
#        [-0.14457097,  1.60220541, -0.27504492, ...,  0.        ,
#          1.        ,  0.        ],
#        [-1.5513183 ,  0.69321022, -0.27504492, ...,  1.        ,
#          1.        ,  0.        ]])

# %%
X_treino.shape
# Out:
# (343, 60)

# %%
y_treino.shape
# Out:
# (343,)

# %%
X_teste.shape
# Out:
# (86, 60)

# %%
y_teste.shape
# Out:
# (86,)

# %% [markdown]
# - RNA TensorFlow + Keras

# %%
import tensorflow as tf
from tensorflow import keras

# %%
# Qual o tamanho da entrada?
X_treino.shape[1:]
# Out:
# (60,)

# %%
model = keras.models.Sequential()
model.add(keras.layers.Dense(64, activation="relu",input_shape=X_treino.shape[1:]))
model.add(keras.layers.Dense(32, activation="relu"))
model.add(keras.layers.Dense(4, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 64)                3904
#
#  dense_10 (Dense)            (None, 32)                2080
#
#  dense_11 (Dense)            (None, 4)                 132
#
# =================================================================
# Total params: 6,116
# Trainable params: 6,116
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Para modelos de classificação com saída esparsa:    # para classificação com saída densa  # para classificação binária:     
model.compile(loss="sparse_categorical_crossentropy", # usar categorical_crossentropy       # usar binary_crossentropy e mudar
              optimizer="sgd",                        #                                     # a ativação da camada de saída
              metrics=["accuracy"])                   #                                     # para sigmoid

# %% [markdown]
# #### Treinamento do modelo

# %%
history = model.fit(X_treino, y_treino, epochs=80, validation_split=0.2)
# Out:
# Epoch 1/80
# 9/9 [==============================] - 1s 46ms/step - loss: 1.6503 - accuracy: 0.0657 - val_loss: 1.4952 - val_accuracy: 0.1594
# Epoch 2/80
# 9/9 [==============================] - 0s 11ms/step - loss: 1.3756 - accuracy: 0.2810 - val_loss: 1.2963 - val_accuracy: 0.4203
# Epoch 3/80
# 9/9 [==============================] - 0s 11ms/step - loss: 1.2157 - accuracy: 0.4708 - val_loss: 1.1687 - val_accuracy: 0.5507
# Epoch 4/80
# 9/9 [==============================] - 0s 10ms/step - loss: 1.1086 - accuracy: 0.5693 - val_loss: 1.0721 - val_accuracy: 0.6232
# Epoch 5/80
# 9/9 [==============================] - 0s 11ms/step - loss: 1.0234 - accuracy: 0.6533 - val_loss: 0.9924 - val_accuracy: 0.6957
# Epoch 6/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.9509 - accuracy: 0.6788 - val_loss: 0.9244 - val_accuracy: 0.7101
# Epoch 7/80
# 9/9 [==============================] - 0s 9ms/step - loss: 0.8870 - accuracy: 0.7299 - val_loss: 0.8652 - val_accuracy: 0.7101
# Epoch 8/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.8307 - accuracy: 0.7336 - val_loss: 0.8146 - val_accuracy: 0.7536
# Epoch 9/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.7824 - accuracy: 0.7409 - val_loss: 0.7717 - val_accuracy: 0.7246
# Epoch 10/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.7425 - accuracy: 0.7409 - val_loss: 0.7352 - val_accuracy: 0.7246
# Epoch 11/80
# 9/9 [==============================] - 0s 13ms/step - loss: 0.7073 - accuracy: 0.7555 - val_loss: 0.7028 - val_accuracy: 0.7391
# Epoch 12/80
# 9/9 [==============================] - 0s 13ms/step - loss: 0.6793 - accuracy: 0.7555 - val_loss: 0.6758 - val_accuracy: 0.7391
# Epoch 13/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.6548 - accuracy: 0.7591 - val_loss: 0.6522 - val_accuracy: 0.7391
# Epoch 14/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.6350 - accuracy: 0.7591 - val_loss: 0.6320 - val_accuracy: 0.7536
# Epoch 15/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.6171 - accuracy: 0.7591 - val_loss: 0.6148 - val_accuracy: 0.7681
# Epoch 16/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.6022 - accuracy: 0.7664 - val_loss: 0.6001 - val_accuracy: 0.7536
# Epoch 17/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.5872 - accuracy: 0.7701 - val_loss: 0.5857 - val_accuracy: 0.7681
# Epoch 18/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5748 - accuracy: 0.7737 - val_loss: 0.5724 - val_accuracy: 0.7681
# Epoch 19/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.5643 - accuracy: 0.7701 - val_loss: 0.5615 - val_accuracy: 0.7681
# Epoch 20/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.5535 - accuracy: 0.7737 - val_loss: 0.5494 - val_accuracy: 0.7971
# Epoch 21/80
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5450 - accuracy: 0.7810 - val_loss: 0.5406 - val_accuracy: 0.7826
# Epoch 22/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.5350 - accuracy: 0.7847 - val_loss: 0.5331 - val_accuracy: 0.8116
# Epoch 23/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.5276 - accuracy: 0.7847 - val_loss: 0.5239 - val_accuracy: 0.8116
# Epoch 24/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5191 - accuracy: 0.7883 - val_loss: 0.5161 - val_accuracy: 0.8116
# Epoch 25/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.5117 - accuracy: 0.7810 - val_loss: 0.5082 - val_accuracy: 0.8261
# Epoch 26/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5050 - accuracy: 0.7847 - val_loss: 0.5003 - val_accuracy: 0.8261
# Epoch 27/80
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4982 - accuracy: 0.7920 - val_loss: 0.4946 - val_accuracy: 0.8261
# Epoch 28/80
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4929 - accuracy: 0.7883 - val_loss: 0.4882 - val_accuracy: 0.8261
# Epoch 29/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4866 - accuracy: 0.7920 - val_loss: 0.4820 - val_accuracy: 0.8261
# Epoch 30/80
# 9/9 [==============================] - 0s 13ms/step - loss: 0.4832 - accuracy: 0.7920 - val_loss: 0.4781 - val_accuracy: 0.8261
# Epoch 31/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4754 - accuracy: 0.7993 - val_loss: 0.4734 - val_accuracy: 0.8261
# Epoch 32/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4695 - accuracy: 0.8102 - val_loss: 0.4666 - val_accuracy: 0.8261
# Epoch 33/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4647 - accuracy: 0.8139 - val_loss: 0.4619 - val_accuracy: 0.8406
# Epoch 34/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4600 - accuracy: 0.8139 - val_loss: 0.4575 - val_accuracy: 0.8406
# Epoch 35/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4574 - accuracy: 0.8139 - val_loss: 0.4535 - val_accuracy: 0.8406
# Epoch 36/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4505 - accuracy: 0.8175 - val_loss: 0.4500 - val_accuracy: 0.8406
# Epoch 37/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.4456 - accuracy: 0.8212 - val_loss: 0.4458 - val_accuracy: 0.8406
# Epoch 38/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4414 - accuracy: 0.8285 - val_loss: 0.4433 - val_accuracy: 0.8406
# Epoch 39/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4375 - accuracy: 0.8175 - val_loss: 0.4400 - val_accuracy: 0.8406
# Epoch 40/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.4340 - accuracy: 0.8248 - val_loss: 0.4372 - val_accuracy: 0.8406
# Epoch 41/80
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4304 - accuracy: 0.8285 - val_loss: 0.4339 - val_accuracy: 0.8406
# Epoch 42/80
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4253 - accuracy: 0.8285 - val_loss: 0.4315 - val_accuracy: 0.8551
# Epoch 43/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4230 - accuracy: 0.8321 - val_loss: 0.4293 - val_accuracy: 0.8406
# Epoch 44/80
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4186 - accuracy: 0.8321 - val_loss: 0.4276 - val_accuracy: 0.8406
# Epoch 45/80
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4162 - accuracy: 0.8321 - val_loss: 0.4257 - val_accuracy: 0.8406
# Epoch 46/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4143 - accuracy: 0.8321 - val_loss: 0.4235 - val_accuracy: 0.8406
# Epoch 47/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4086 - accuracy: 0.8321 - val_loss: 0.4218 - val_accuracy: 0.8406
# Epoch 48/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4056 - accuracy: 0.8358 - val_loss: 0.4204 - val_accuracy: 0.8261
# Epoch 49/80
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4020 - accuracy: 0.8321 - val_loss: 0.4180 - val_accuracy: 0.8406
# Epoch 50/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4008 - accuracy: 0.8431 - val_loss: 0.4188 - val_accuracy: 0.8406
# Epoch 51/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3963 - accuracy: 0.8321 - val_loss: 0.4156 - val_accuracy: 0.8116
# Epoch 52/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3929 - accuracy: 0.8321 - val_loss: 0.4151 - val_accuracy: 0.8261
# Epoch 53/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3910 - accuracy: 0.8321 - val_loss: 0.4150 - val_accuracy: 0.8406
# Epoch 54/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3874 - accuracy: 0.8394 - val_loss: 0.4119 - val_accuracy: 0.8261
# Epoch 55/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3851 - accuracy: 0.8321 - val_loss: 0.4114 - val_accuracy: 0.8116
# Epoch 56/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3825 - accuracy: 0.8358 - val_loss: 0.4115 - val_accuracy: 0.8261
# Epoch 57/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3804 - accuracy: 0.8394 - val_loss: 0.4107 - val_accuracy: 0.8261
# Epoch 58/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3792 - accuracy: 0.8358 - val_loss: 0.4090 - val_accuracy: 0.8116
# Epoch 59/80
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3751 - accuracy: 0.8431 - val_loss: 0.4079 - val_accuracy: 0.8116
# Epoch 60/80
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3718 - accuracy: 0.8358 - val_loss: 0.4078 - val_accuracy: 0.8116
# Epoch 61/80
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3725 - accuracy: 0.8358 - val_loss: 0.4068 - val_accuracy: 0.8116
# Epoch 62/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3673 - accuracy: 0.8431 - val_loss: 0.4080 - val_accuracy: 0.8116
# Epoch 63/80
# 9/9 [==============================] - 0s 14ms/step - loss: 0.3672 - accuracy: 0.8467 - val_loss: 0.4068 - val_accuracy: 0.8116
# Epoch 64/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3647 - accuracy: 0.8467 - val_loss: 0.4065 - val_accuracy: 0.8116
# Epoch 65/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3626 - accuracy: 0.8431 - val_loss: 0.4063 - val_accuracy: 0.8116
# Epoch 66/80
# 9/9 [==============================] - 0s 13ms/step - loss: 0.3601 - accuracy: 0.8431 - val_loss: 0.4077 - val_accuracy: 0.8116
# Epoch 67/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3575 - accuracy: 0.8394 - val_loss: 0.4066 - val_accuracy: 0.8116
# Epoch 68/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3563 - accuracy: 0.8467 - val_loss: 0.4057 - val_accuracy: 0.8116
# Epoch 69/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3564 - accuracy: 0.8504 - val_loss: 0.4075 - val_accuracy: 0.8116
# Epoch 70/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3527 - accuracy: 0.8431 - val_loss: 0.4062 - val_accuracy: 0.8116
# Epoch 71/80
# 9/9 [==============================] - 0s 13ms/step - loss: 0.3507 - accuracy: 0.8504 - val_loss: 0.4063 - val_accuracy: 0.8261
# Epoch 72/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3484 - accuracy: 0.8504 - val_loss: 0.4071 - val_accuracy: 0.8116
# Epoch 73/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3480 - accuracy: 0.8504 - val_loss: 0.4076 - val_accuracy: 0.7971
# Epoch 74/80
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3488 - accuracy: 0.8504 - val_loss: 0.4066 - val_accuracy: 0.8116
# Epoch 75/80
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3430 - accuracy: 0.8577 - val_loss: 0.4061 - val_accuracy: 0.8116
# Epoch 76/80
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3419 - accuracy: 0.8504 - val_loss: 0.4068 - val_accuracy: 0.8261
# Epoch 77/80
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3403 - accuracy: 0.8504 - val_loss: 0.4072 - val_accuracy: 0.8261
# Epoch 78/80
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3402 - accuracy: 0.8431 - val_loss: 0.4074 - val_accuracy: 0.8261
# Epoch 79/80
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3366 - accuracy: 0.8431 - val_loss: 0.4090 - val_accuracy: 0.7971
# Epoch 80/80
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3358 - accuracy: 0.8540 - val_loss: 0.4092 - val_accuracy: 0.8261

# %% [markdown]
# #### Avaliação da evolução do treinamento

# %%
pd.DataFrame(history.history).plot(figsize=(10,6))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %% [markdown]
# #### Avaliação do desempenho do modelo treinado

# %%
y_previsto_rna_proba = model.predict(X_teste)
# Out:
# 3/3 [==============================] - 0s 0s/step

# %%
np.round(y_previsto_rna_proba,decimals=2)
# Out:
# array([[0.11, 0.89, 0.  , 0.  ],
#        [0.18, 0.82, 0.  , 0.  ],
#        [0.98, 0.02, 0.  , 0.  ],
#        [0.23, 0.76, 0.  , 0.01],
#        [0.63, 0.37, 0.  , 0.  ],
#        [0.11, 0.89, 0.  , 0.  ],
#        [0.18, 0.82, 0.  , 0.  ],
#        [0.98, 0.02, 0.  , 0.  ],
#        [0.39, 0.6 , 0.  , 0.  ],
#        [0.09, 0.9 , 0.  , 0.  ],
#        [0.04, 0.96, 0.  , 0.  ],
#        [0.33, 0.67, 0.  , 0.  ],
#        [0.16, 0.84, 0.  , 0.  ],
#        [0.1 , 0.9 , 0.  , 0.  ],
#        [0.19, 0.81, 0.  , 0.  ],
#        [0.36, 0.63, 0.  , 0.  ],
#        [0.2 , 0.8 , 0.  , 0.  ],
#        [0.98, 0.02, 0.  , 0.  ],
#        [0.14, 0.85, 0.  , 0.  ],
#        [0.35, 0.65, 0.  , 0.  ],
#        [0.92, 0.08, 0.  , 0.  ],
#        [0.19, 0.81, 0.  , 0.  ],
#        [0.48, 0.52, 0.  , 0.  ],
#        [0.22, 0.78, 0.  , 0.  ],
#        [0.05, 0.94, 0.  , 0.  ],
#        [0.28, 0.72, 0.  , 0.  ],
#        [0.94, 0.06, 0.  , 0.  ],
#        [0.27, 0.73, 0.  , 0.  ],
#        [0.24, 0.75, 0.  , 0.  ],
#        [0.99, 0.01, 0.  , 0.  ],
#        [0.47, 0.52, 0.  , 0.  ],
#        [0.66, 0.33, 0.  , 0.01],
#        [0.97, 0.03, 0.  , 0.  ],
#        [0.17, 0.83, 0.  , 0.  ],
#        [0.23, 0.77, 0.  , 0.  ],
#        [0.14, 0.85, 0.  , 0.  ],
#        [0.13, 0.86, 0.  , 0.  ],
#        [0.27, 0.72, 0.  , 0.  ],
#        [0.94, 0.06, 0.  , 0.  ],
#        [0.1 , 0.89, 0.  , 0.  ],
#        [0.95, 0.05, 0.  , 0.  ],
#        [0.86, 0.13, 0.  , 0.  ],
#        [0.39, 0.61, 0.  , 0.  ],
#        [0.21, 0.79, 0.  , 0.  ],
#        [0.16, 0.84, 0.  , 0.  ],
#        [0.18, 0.81, 0.  , 0.01],
#        [0.09, 0.9 , 0.  , 0.  ],
#        [0.14, 0.86, 0.  , 0.  ],
#        [0.16, 0.83, 0.  , 0.  ],
#        [0.58, 0.42, 0.  , 0.  ],
#        [0.17, 0.82, 0.  , 0.  ],
#        [0.97, 0.03, 0.  , 0.  ],
#        [0.35, 0.65, 0.  , 0.  ],
#        [0.06, 0.94, 0.  , 0.  ],
#        [0.96, 0.04, 0.  , 0.  ],
#        [0.17, 0.83, 0.  , 0.  ],
#        [0.19, 0.8 , 0.  , 0.  ],
#        [0.07, 0.92, 0.  , 0.  ],
#        [0.19, 0.81, 0.  , 0.  ],
#        [0.05, 0.95, 0.  , 0.  ],
#        [0.24, 0.76, 0.  , 0.  ],
#        [0.67, 0.33, 0.  , 0.  ],
#        [0.61, 0.39, 0.  , 0.  ],
#        [0.95, 0.05, 0.  , 0.  ],
#        [0.09, 0.91, 0.  , 0.  ],
#        [0.08, 0.92, 0.  , 0.  ],
#        [0.31, 0.69, 0.  , 0.  ],
#        [0.14, 0.86, 0.  , 0.  ],
#        [0.94, 0.06, 0.  , 0.  ],
#        [0.97, 0.02, 0.  , 0.  ],
#        [0.26, 0.74, 0.  , 0.  ],
#        [0.04, 0.96, 0.  , 0.  ],
#        [0.16, 0.84, 0.  , 0.  ],
#        [0.14, 0.86, 0.  , 0.  ],
#        [0.26, 0.73, 0.  , 0.  ],
#        [0.12, 0.87, 0.  , 0.01],
#        [0.1 , 0.9 , 0.  , 0.  ],
#        [0.39, 0.6 , 0.  , 0.01],
#        [0.7 , 0.29, 0.  , 0.  ],
#        [0.91, 0.08, 0.  , 0.  ],
#        [0.45, 0.54, 0.  , 0.01],
#        [0.87, 0.13, 0.  , 0.  ],
#        [0.14, 0.86, 0.  , 0.  ],
#        [0.14, 0.86, 0.  , 0.  ],
#        [0.96, 0.04, 0.  , 0.  ],
#        [0.97, 0.02, 0.  , 0.  ]], dtype=float32)
